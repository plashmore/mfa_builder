# %% [markdown]
# For Dataframes:

# %%
import pandas as pd

# %% [markdown]
# For MFA function:

# %%
import prince

# %% [markdown]
# While loop to include CSVs of groupings

# %%
answer="yes"
index=1
groups={}
master=pd.DataFrame()
while answer!="no":
    answer=input("Do you have more classes to include (yes/no):")
    while answer != "yes" and answer != "no":
        answer=input("Please input 'yes' or 'no':")
    if answer == "yes":
        file_name=input("Filename (include .csv):")
        df=pd.read_csv(file_name)
        group_name=input("Group name:")
        group_cols=df.columns.tolist()[4:]
        if index==1:
            master=df
        else:
            df2=df.drop(df.columns[0], axis=1)
            master=pd.concat([master,df2], axis=1)
            
    groups[group_name]=group_cols
    index=index+1

mfa=prince.MFA(n_components=2, n_iter=3, copy=True, check_input=True, engine='sklearn', random_state=42)
master2=master.drop(df.columns[0:4],axis=1)
mfa=mfa.fit(master2, groups=groups)
mfa.plot(master2, x_component=0, y_component=1)
# Out:
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): acetal.csv
# Group name: acetals
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): acetate.csv
# Group name: acetates
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): alcohol.csv
# Group name: alcohols
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): phenol.csv
# Group name: phenols
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): sat_ester.csv
# Group name: saturated esters
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): terpene.csv
# Group name: terpenes
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): un_ester.csv
# Group name: unsaturated esters
# Do you have more classes to include (yes/no): yes
# Filename (include .csv): unknown.csv
# Group name: unknowns
# Do you have more classes to include (yes/no): no
# alt.Chart(...)
